# %%
import sys

if 'google.colab' in sys.modules:
    print("✅ Estás ejecutando en Google Colab")
    print(f"📍 Versión de Python: {sys.version}")

else:
    print("⚠️ No estás en Google Colab")
    print("Este notebook está diseñado para ejecutarse en Colab")

# %%
if 'google.colab' in sys.modules:
    print("✅ Estás ejecutando en Google Colab")
    # !pip install ultralytics==8.4.21
    # !pip install supervision==0.27.0.post1
    # !pip install albumentations==2.0.8
else:
    print("⚠️ No estás en Google Colab")
    print("Este notebook está diseñado para ejecutarse en Colab")

# %%
from src import train_yolo as train
result = train.train_model(epochs = 50)
# Out:
# Dataset unzipped.
# models directory validated.
# ...
# Ultralytics 8.4.21  Python-3.11.9 torch-2.10.0+cpu CPU (AMD Ryzen 5 8645HS w/ Radeon 760M Graphics)
# ...

# %%
from src import inference as inf
res = inf.detect_house(image_path = './images/valid/images/real_041_MI_HOUSE_png.rf.0e452c2b0051f1281e7c048c3f3d5605.jpg' )
# Out:
# 0: 640x640 1 casa, 120.7ms
# Speed: 43.9ms preprocess, 120.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Imagen anotada guardada como 'annotated_image.jpg'
